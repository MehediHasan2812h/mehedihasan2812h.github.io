# %% [markdown]
# <a href="https://colab.research.google.com/github/MehediHasan2812h/mehedihasan2812h.github.io/blob/main/class_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num1=int(input("enter your first number x"))     #arithmetic  operators
num2=int(input("enter your secound number y"))
# Out:
# enter your first number x3
# enter your secound number y2

# %%
add=num1+num2
print(add)
# Out:
# 5

# %%
sub=num1-num2
print(sub)
# Out:
# 1

# %%
mul=num1*num2
print(mul)
# Out:
# 6

# %%
div=num1/num2
print(div)
# Out:
# 1.5

# %%
exp=num1**num2
print(exp)
# Out:
# 9

# %%
fdiv=num1//num2
print(fdiv)
# Out:
# 1

# %%
print(f"""addition:{add},
subtraction:{sub},
      multiplication:{mul}
      division:{div},
      exponent:{exp},
      florrdivision:{fdiv}""")
# Out:
# addition:5,
# subtraction:1,
#       multiplication:6
#       division:1.5,
#       exponent:9,
#       florrdivision:1

# %%
# logical operators #and
a=5
b=7
print(a<b and b>a)
# Out:
# True

# %%
print(a>b or b>a) #or
# Out:
# True

# %%
print(not(b>a)) # not exactly it is true but not change it
# Out:
# False

# %%
# membership operator in , not in
a=5
b={1,2,3,4,5}
print(a in b)
# Out:
# True

# %%
a=6
b={1,2,3,4,5}
print(a not in b)
# Out:
# True

# %%
a=5
b={1,2,3,4,67,8}
print(a in b)
# Out:
# False

# %%
a=7
b={1,3,5,7,8}
print(a not in b)
# Out:
# False

# %%
#identity operator is ,is not
a=10
b=a
c=100
d=10
print(a is b)
# Out:
# True

# %%
print(b is c)
# Out:
# False

# %%
print(c is d)
# Out:
# False

# %%
print(d is a)
# Out:
# True

# %%
x= 5+2*3**2//4-1
print(x)
# Out:
# 8
