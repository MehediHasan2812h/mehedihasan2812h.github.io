# %% [markdown]
# <a href="https://colab.research.google.com/github/MehediHasan2812h/mehedihasan2812h.github.io/blob/main/Copy_of_class_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
  name ="nasim"

# %%
print(name)
# Out:
# nasim

# %%
type(name)
# Out:
# str

# %%
name = input("wht is your name friend")
# Out:
# wht is your name friendmuhammad

# %%
print(name)
# Out:
# muhammad

# %%
age=input("what is your age muhammad")
# Out:
# what is your age muhammad63

# %%
type(age)
# Out:
# str

# %%
age=int(input("bondhu tmr age koto"))
# Out:
# bondhu tmr age koto63

# %%
type(age)
# Out:
# int

# %%
data = "saim"

# %%
print(data)
# Out:
# saim
